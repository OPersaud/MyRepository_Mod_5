# %%
# OMESH PERSAUD (1089283)                                MODULE 5 EXERCISE 1                                             DATE: 01 MARCH 2022

#------------------------------------------------DESIGN OF GUI FOR BACK WATER CURVE-----------------------------------------------------------

#------------------------------------------------------IMPORTING OF LIBRARIES-----------------------------------------------------------------
from bokeh.io import output_file, show, curdoc
from bokeh.layouts import widgetbox, gridplot
from bokeh.models import CustomJS, Dropdown
from bokeh.models.widgets import  Slider, Button, TextInput, RadioButtonGroup, PreText, Paragraph
from bokeh.palettes import Viridis3
from bokeh.plotting import figure
#--------------------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------------------NAMING OF OUTPUT HTML FILE--------------------------------------------------------------
output_file("GUI_BACKWATERCURVE.html")
#--------------------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------DESCRIPTION LINES FOR IMPROVING USER EXPERIENCE----------------------------------------------------
description_1 = PreText(text="""Please select one of the three Hyrdaulic Models which are available below.""",width=20, height=40, style={'font-size':'16pt', 
                     'color': 'blue', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})


description_2 = PreText(text="""Please select the method of solution for the BWC.""",width=20, height=30, style={'font-size':'10pt', 
                     'color': 'grey', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})


description_3 = PreText(text="""Please enter physical and numerical parameters.""",width=20, height=30, style={'font-size':'10pt', 
                     'color': 'grey', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})


description_4 = PreText(text="""Please see plot generated blow.""",width=20, height=30, style={'font-size':'10pt', 
                     'color': 'grey', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})


description_5 = PreText(text="""Click this button to run the model. """,width=20, height=35, style={'font-size':'10pt', 
                     'color': 'grey', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})


description_6 = PreText(text="""Additional features avialable: """,width=20, height=35, style={'font-size':'10pt', 
                     'color': 'black', 
                     'font-weight': 'bold', 
                     'font-family': 'Arial, Helvetica, sans-serif'})

#--------------------------------------------------------------------------------------------------------------------------------------------


#----------------------------------------------------GROUP BUTTON TO SELECT TYPE OF MODEL----------------------------------------------------
button_group = RadioButtonGroup(labels=["BACK WATER CURVE MODEL", "SUGAWARA TANK MODEL", "1-D FREE SURFACE FLOW MODEL"], active=0)
#--------------------------------------------------------------------------------------------------------------------------------------------


#--------------------------------------------DROP DOWN MENU TO SELECT EXPLICIT OR IMPLICIT----------------------------------------------------
menu = [("Explicit Method", "item_1"), ("Implicit Method", "item_2")]
dropdown = Dropdown(label="Select an option", button_type="warning", menu=menu)
dropdown.js_on_event("menu_item_click", CustomJS(code="console.log('dropdown: ' + this.item, this.toString())"))
#--------------------------------------------------------------------------------------------------------------------------------------------


#--------------------------------------------SLIDER BARS TO ADJUST PARAMETERS TO UDPATE PLOT--------------------------------------------------
slider1 = Slider(start=1, end=100, value=20, step=.1, title="Channel Width")
#--------------------------------------------------------------------------------------------------------------------------------------------

slider2 = Slider(start=1, end=10000, value=2000, step=10, title="Channel Length")
#--------------------------------------------------------------------------------------------------------------------------------------------

slider3 = Slider(start=20, end=60, value=30, step=1, title="Chezy Coefficient")
#--------------------------------------------------------------------------------------------------------------------------------------------

slider4 = Slider(start=1, end=5000, value=500, step=1, title="Discharge")
#--------------------------------------------------------------------------------------------------------------------------------------------

slider5 = Slider(start=1, end=20, value=3, step=0.20, title="Intial Depth Downstream")
#--------------------------------------------------------------------------------------------------------------------------------------------

slider6 = Slider(start=1, end=500, value=3, step=1, title="dx")
#--------------------------------------------------------------------------------------------------------------------------------------------


#--------------------------------------------INPUT FOR FLOAT VALUE FOR So and Delta x---------------------------------------------------------

text_input1 = TextInput(value="Please enter float value.", title="Bed slope:")
text_input1.js_on_change("value", CustomJS(code="""
    console.log('text_input: value=' + this.value, this.toString())
"""))


text_input2 = TextInput(value="Please enter integer value.", title="Number of iterations:")
text_input2.js_on_change("value", CustomJS(code="""
    console.log('text_input: value=' + this.value, this.toString())
"""))


text_input3 = TextInput(value="Please enter float value.", title="Convergence Criteria (Tolerance):")
text_input3.js_on_change("value", CustomJS(code="""
    console.log('text_input: value=' + this.value, this.toString())
"""))
#--------------------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------------BUTTON TO PERFORM COMPUTATION-----------------------------------------------------------------
button_0 = Button(label="Run the Model for the Back Water Curve", button_type="success")
#--------------------------------------------------------------------------------------------------------------------------------------------


#---------------------------------------------BUTTONs TO EXPORT DATA FROM MODEL-----------------------------------------------------------------
button_1 = Button(label="Click to export/save datasets.")
button_2 = Button(label="Click to export/save graph. ")
#--------------------------------------------------------------------------------------------------------------------------------------------


#--------------------------------------------SAMPLE DATA FOR IMPLEMENTING A PLOT-------------------------------------------------------------
x = list(range(11))
y0 = x
y1 = [10 - i for i in x]
y2 = [abs(i - 5) for i in x]
# create plots
p1 = figure(plot_width=250, plot_height=250, title="The plot for the back water curve will be implemented in place of this plot.")
p1.circle(x, y0, size=10, color=Viridis3[0])
#--------------------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------INPUTTING & ARRANGING WIDGES ON HTML OUTPUT PAGE----------------------------------------------------
grid = gridplot([  description_1, None, None,     None, button_group, None,    None, description_2, None,      None, dropdown, None,      None, description_3, None,    slider1, slider2,slider3,       slider5, slider4, slider6,    text_input1, text_input2, text_input3,       description_4, None, None,     None, p1, None,      description_5, button_0, None,   description_6, None, None,   button_1, button_2, None ], ncols=3, plot_width=500, plot_height=500)
#--------------------------------------------------------------------------------------------------------------------------------------------


#-----------------------------------------SHOWING THE RESULTS----------------------------------------------------
show(grid)
#--------------------------------------------------------------------------------------------------------------------------------------------
